# %% [markdown]
# # Setup Google Colab with GitHub via Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %mkdir ChamiML

# %%
# %cd /content/drive/MyDrive/ChamiML/
# Out:
# /content/drive/MyDrive/ChamiML

# %%
# !git clone https://github.com/Safe-Place/ChaMi-ML.git
# Out:
# Cloning into 'ChaMi-ML'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# %ls -a
# Out:
# ChaMi-ML/

# %%
from getpass import getpass

uname = input('Uname : ')
password = getpass('Password : ')
email = input('email : ')
# !git config --global user.email '$email'
# !git config --global user.name '$uname'
# !git config --global user.password '$password'
# Out:
# Uname : afhabibieee
# Password : ··········
# email : adilfaruqhabibi@gmail.com

# %%
# !git config --global credential.helper store

# %%
# !git config --list
# Out:
# user.email=adilfaruqhabibi@gmail.com
# user.name=afhabibieee
# user.password=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
# credential.helper=store
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://github.com/afhabibieee/test-github-colab.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*

# %% [markdown]
# # All git commands to work remotely

# %%
# move ipynb training to your drive repository

# %%
# %cp

# %%
# write the command here...

# !git add setup_remote.ipynb
# !git commit -m "initial commit to add default git on colab for data and modeling"
# Out:
# fatal: Unable to create '/content/drive/MyDrive/ChamiML/.git/index.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
# fatal: Unable to create '/content/drive/MyDrive/ChamiML/.git/index.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.

# %%
# !git clo
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	deleted:    setup_remote.ipynb
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	setup_remote.ipynb

# %%
# !git remote add origin https://github.com/Safe-Place/ChaMi-ML.git

# %%
# !git remote rm origin

# %%
# !git remote -v
# Out:
# origin	https://github.com/Safe-Place/ChaMi-ML.git (fetch)
# origin	https://github.com/Safe-Place/ChaMi-ML.git (push)

# %%
# !git push -u origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
