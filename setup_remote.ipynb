# %% [markdown]
# # Setup Google Colab with GitHub via Google Drive

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# Set path
import os
path = ['MLHabibi', 'MLCim', 'MLFaren']
PATH = os.path.join('/content/drive/MyDrive/', path[0]) # ex MLHabibi

# %%
# %cd '$PATH'
# Out:
# /content/drive/MyDrive/MLHabibi

# %%
# Check directory
# %pwd
# Out:
# '/content/drive/MyDrive/MLHabibi'

# %%
token = 'ghp_eR5hnHeb3uXrFhcaSAAkfjtxxbXXXXXXXXXX'  # ex token
# !git clone https://'$token'@github.com/Safe-Place/ChaMi-ML

# %%
# %cd ChaMi-ML/
# Out:
# /content/drive/MyDrive/MLHabibi/ChaMi-ML

# %%
# %ls -a
# Out:
# Face_train.ipynb  .git/  .gitignore  README.md  setup_remote.ipynb

# %%
#from getpass import getpass

uname = input('Uname : ')
#password = getpass('Password : ')
email = input('email : ')
# !git config --global user.email '$email'
# !git config --global user.name '$uname'
#!git config --global user.password '$password'
# Out:
# Uname : afhabibieee
# email : adilfaruqhabibi@gmail.com

# %%
# !git config --global credential.helper store

# %% [markdown]
# # All git commands to work remotely

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git log

# %%
# write the command here...

# !git add Face_train.ipynb

# %%
# !git commit -m "initial commit to jupyter notebook env training"
# Out:
# [main c4877fd] initial commit to jupyter notebook env training
#  1 file changed, 1 insertion(+)
#  create mode 100644 Face_train.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git remote rm origin

# %%
# !git remote add origin https://'$token'@github.com/Safe-Place/ChaMi-ML

# %%
# !git remote -v

# %%
# !git push -u origin main

# %%
# cek directory
# %ls -a

# %%
# !git pull
